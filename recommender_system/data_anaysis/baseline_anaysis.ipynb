# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from utils.process_data import user_item_interaction_scores
from utils.data_exploration import perform_eda
from parquet_data_reader import ParquetDataReader
from models.baseline import UserItemBiasRecommender


import polars as pl
pl.Config.set_tbl_cols(-1)
import numpy as np
parquet_reader = ParquetDataReader()

# %%
train_behavior_df = parquet_reader.read_data("../../data/train/behaviors.parquet")
embeddings_df = parquet_reader.read_data("../../data/document_vector.parquet")
article_df = parquet_reader.read_data("../../data/articles.parquet")
test_behavior_df = parquet_reader.read_data("../../data/validation/behaviors.parquet")
processed_behavior_df = user_item_interaction_scores(train_behavior_df, article=article_df)

# %%
from utils.data_exploration import perform_eda

# %%
# 1. EDA on Train Behaviors
perform_eda(train_behavior_df, name="Train Behaviors")
# Out:
# === Train Behaviors Schema ===
# Schema([('impression_id', UInt32), ('article_id', Int32), ('impression_time', Datetime(time_unit='us', time_zone=None)), ('read_time', Float32), ('scroll_percentage', Float32), ('device_type', Int8), ('article_ids_inview', List(Int32)), ('article_ids_clicked', List(Int32)), ('user_id', UInt32), ('is_sso_user', Boolean), ('gender', Int8), ('postcode', Int8), ('age', Int8), ('is_subscriber', Boolean), ('session_id', UInt32), ('next_read_time', Float32), ('next_scroll_percentage', Float32)])
#
# === Train Behaviors describe() ===
#     statistic  impression_id    article_id             impression_time  \
# 0       count   2.328870e+05  7.042100e+04                      232887
# 1  null_count   0.000000e+00  1.624660e+05                           0
# 2        mean   2.882795e+08  9.765423e+06  2023-05-21 16:43:32.126653
# 3         std   1.683194e+08  1.296827e+05                        None
# 4         min   1.494740e+05  3.198681e+06         2023-05-18 07:00:01
# 5         25%   1.420387e+08  9.772032e+06         2023-05-19 18:51:21
# 6         50%   2.903336e+08  9.774297e+06         2023-05-21 16:46:53
# 7         75%   4.331668e+08  9.776882e+06         2023-05-23 10:46:53
# 8         max   5.801007e+08  9.780271e+06         2023-05-25 06:59:58
#
#        read_time  scroll_percentage    device_type  article_ids_inview  \
# 0  232887.000000       69098.000000  232887.000000            232887.0
# 1       0.000000      163789.000000       0.000000                 0.0
# 2      43.901806          99.566208       1.685521                 NaN
# 3      90.299965           4.944662       0.519545                 NaN
# 4       0.000000           7.000000       1.000000                 NaN
# 5      11.000000         100.000000       1.000000                 NaN
# 6      21.000000         100.000000       2.000000                 NaN
# 7      45.000000         100.000000       2.000000                 NaN
# 8    1799.000000         100.000000       3.000000                 NaN
#
#    article_ids_clicked       user_id    is_sso_user         gender  \
# 0             232887.0  2.328870e+05  232887.000000   16219.000000
# 1                  0.0  0.000000e+00       0.000000  216668.000000
# 2                  NaN  1.313502e+06       0.101337       0.107590
# 3                  NaN  7.370205e+05            NaN       0.309871
# 4                  NaN  1.006800e+04       0.000000       0.000000
# 5                  NaN  6.866610e+05            NaN       0.000000
# 6                  NaN  1.328699e+06            NaN       0.000000
# 7                  NaN  1.954176e+06            NaN       0.000000
# 8                  NaN  2.590637e+06       1.000000       1.000000
#
#         postcode            age  is_subscriber    session_id  next_read_time  \
# 0    4673.000000    6341.000000  232887.000000  2.328870e+05   226669.000000
# 1  228214.000000  226546.000000       0.000000  0.000000e+00     6218.000000
# 2       1.438048      55.013405       0.066212  9.891061e+05       68.649857
# 3       1.436164      13.891898            NaN  5.682560e+05      172.633560
# 4       0.000000       0.000000       0.000000  4.060000e+02        0.000000
# 5       0.000000      50.000000            NaN  5.004290e+05        7.000000
# 6       1.000000      60.000000            NaN  9.911210e+05       21.000000
# 7       3.000000      60.000000            NaN  1.477665e+06       62.000000
# 8       4.000000      90.000000       1.000000  2.030118e+06     1799.000000
#
#    next_scroll_percentage
# 0           206617.000000
# 1            26270.000000
# 2               69.112617
# 3               32.253510
# 4                0.000000
# 5               36.000000
# 6               80.000000
# 7              100.000000
# 8              100.000000
# === Train Behaviors head() ===
#    impression_id  article_id     impression_time  read_time  \
# 0         149474         NaN 2023-05-24 07:47:53       13.0
# 1         150528         NaN 2023-05-24 07:33:25       25.0
# 2         153068   9778682.0 2023-05-24 07:09:04       78.0
# 3         153070   9777492.0 2023-05-24 07:13:14       26.0
# 4         153071   9778623.0 2023-05-24 07:11:08      125.0
#
#    scroll_percentage  device_type  \
# 0                NaN            2
# 1                NaN            2
# 2              100.0            1
# 3              100.0            1
# 4              100.0            1
#
#                                   article_ids_inview article_ids_clicked  \
# 0  [9778623, 9778682, 9778669, 9778657, 9778736, ...           [9778657]
# 1  [9778718, 9778728, 9778745, 9778669, 9778657, ...           [9778623]
# 2  [9778657, 9778669, 9772866, 9776259, 9756397, ...           [9778669]
# 3  [9020783, 9778444, 9525589, 7213923, 9777397, ...           [9778628]
# 4  [9777492, 9774568, 9565836, 9335113, 9771223, ...           [9777492]
#
#    user_id  is_sso_user  gender  postcode  age  is_subscriber  session_id  \
# 0   139836        False     NaN       NaN  NaN          False         759
# 1   143471        False     NaN       NaN  NaN          False        1240
# 2   151570        False     NaN       NaN  NaN          False        1976
# 3   151570        False     NaN       NaN  NaN          False        1976
# 4   151570        False     NaN       NaN  NaN          False        1976
#
#    next_read_time  next_scroll_percentage
# 0             7.0                    22.0
# 1           287.0                   100.0
# 2            45.0                   100.0
# 3             4.0                    18.0
# 4            26.0                   100.0
# === Train Behaviors Null Counts ===
#    impression_id  article_id  impression_time  read_time  scroll_percentage  \
# 0              0      162466                0          0             163789
#
#    device_type  article_ids_inview  article_ids_clicked  user_id  is_sso_user  \
# 0            0                   0                    0        0            0
#
#    gender  postcode     age  is_subscriber  session_id  next_read_time  \
# 0  216668    228214  226546              0           0            6218
#
#    next_scroll_percentage
# 0                   26270

# %%
# 2. EDA on Document Embeddings
perform_eda(embeddings_df, name="Document Embeddings")
# Out:
# === Document Embeddings Schema ===
# Schema([('article_id', Int32), ('document_vector', List(Float32))])
#
# === Document Embeddings describe() ===
#     statistic    article_id  document_vector
# 0       count  1.255410e+05         125541.0
# 1  null_count  0.000000e+00              0.0
# 2        mean  7.408473e+06              NaN
# 3         std  2.144212e+06              NaN
# 4         min  3.000022e+06              NaN
# 5         25%  5.249139e+06              NaN
# 6         50%  8.043074e+06              NaN
# 7         75%  9.455107e+06              NaN
# 8         max  9.803607e+06              NaN
# === Document Embeddings head() ===
#    article_id                                    document_vector
# 0     3000022  [0.06542388, -0.047424573, 0.06384871, -0.0014...
# 1     3000063  [0.028815078, -0.00016637295, 0.055056807, 0.0...
# 2     3000613  [0.037971217, 0.03392251, 0.027297212, 0.01708...
# 3     3000700  [0.04652399, 0.0029133065, 0.06280604, -0.0051...
# 4     3000840  [0.014736942, 0.024067875, 0.0051865038, 0.041...
# === Document Embeddings Null Counts ===
#    article_id  document_vector
# 0           0                0

# %%
# 3. EDA on Articles
perform_eda(article_df, name="Articles")
# Out:
# === Articles Schema ===
# Schema([('article_id', Int32), ('title', String), ('subtitle', String), ('last_modified_time', Datetime(time_unit='us', time_zone=None)), ('premium', Boolean), ('body', String), ('published_time', Datetime(time_unit='us', time_zone=None)), ('image_ids', List(Int64)), ('article_type', String), ('url', String), ('ner_clusters', List(String)), ('entity_groups', List(String)), ('topics', List(String)), ('category', Int16), ('subcategory', List(Int16)), ('category_str', String), ('total_inviews', Int32), ('total_pageviews', Int32), ('total_read_time', Float32), ('sentiment_score', Float32), ('sentiment_label', String)])
#
# === Articles describe() ===
#     statistic    article_id  \
# 0       count  2.073800e+04
# 1  null_count  0.000000e+00
# 2        mean  8.779823e+06
# 3         std  1.668318e+06
# 4         min  3.001353e+06
# 5         25%  8.834714e+06
# 6         50%  9.609911e+06
# 7         75%  9.745302e+06
# 8         max  9.803607e+06
#
#                                                title  \
# 0                                              20738
# 1                                                  0
# 2                                               None
# 3                                               None
# 4
# 5                                               None
# 6                                               None
# 7                                               None
# 8  ”Vi ved, hvor vigtigt det er for Brøndbys fans...
#
#                                             subtitle  \
# 0                                              20738
# 1                                                  0
# 2                                               None
# 3                                               None
# 4
# 5                                               None
# 6                                               None
# 7                                               None
# 8  “Nøgen i mine sutsko” er det korte og kontante...
#
#            last_modified_time       premium  \
# 0                       20738  20738.000000
# 1                           0      0.000000
# 2  2023-06-30 18:38:02.157777      0.236474
# 3                        None           NaN
# 4         2023-06-29 06:20:33      0.000000
# 5         2023-06-29 06:43:39           NaN
# 6         2023-06-29 06:48:06           NaN
# 7         2023-06-29 06:48:55           NaN
# 8         2024-01-25 05:15:50      1.000000
#
#                                                 body  \
# 0                                              20738
# 1                                                  0
# 2                                               None
# 3                                               None
# 4
# 5                                               None
# 6                                               None
# 7                                               None
# 8  • Er du single?\n– Nej, jeg har den bedste man...
#
#                published_time  image_ids     article_type  ... entity_groups  \
# 0                       20738    18860.0            20738  ...       20738.0
# 1                           0     1878.0                0  ...           0.0
# 2  2021-04-06 17:43:51.156668        NaN             None  ...           NaN
# 3                        None        NaN             None  ...           NaN
# 4         1998-12-27 12:05:00        NaN  article_default  ...           NaN
# 5         2021-09-12 21:30:00        NaN             None  ...           NaN
# 6         2023-02-01 12:03:31        NaN             None  ...           NaN
# 7         2023-05-02 10:13:24        NaN             None  ...           NaN
# 8         2023-07-11 05:05:36        NaN    article_webtv  ...           NaN
#
#     topics      category  subcategory  category_str  total_inviews  \
# 0  20738.0  20738.000000      20738.0         20738   9.968000e+03
# 1      0.0      0.000000          0.0             0   1.077000e+04
# 2      NaN    488.540602          NaN          None   3.548798e+05
# 3      NaN    726.482571          NaN          None   3.114681e+05
# 4      NaN      2.000000          NaN          auto   1.000000e+00
# 5      NaN    140.000000          NaN          None   1.592230e+05
# 6      NaN    142.000000          NaN          None   3.379390e+05
# 7      NaN    498.000000          NaN          None   4.828270e+05
# 8      NaN   2975.000000          NaN           vin   4.138598e+06
#
#   total_pageviews  total_read_time  sentiment_score  sentiment_label
# 0    9.856000e+03     9.856000e+03     20738.000000            20738
# 1    1.088200e+04     1.088200e+04         0.000000                0
# 2    6.215521e+04     3.767574e+06         0.824983             None
# 3    6.370662e+04     4.988664e+06         0.157419             None
# 4    1.000000e+00     0.000000e+00         0.344900         Negative
# 5    1.281300e+04     6.677810e+05         0.693200             None
# 6    4.934100e+04     2.767916e+06         0.870400             None
# 7    9.219700e+04     5.252501e+06         0.972600             None
# 8    1.637751e+06     2.181756e+08         0.998300         Positive
#
# [9 rows x 22 columns]
# === Articles head() ===
#    article_id                             title  \
# 0     3001353      Natascha var ikke den første
# 1     3003065         Kun Star Wars tjente mere
# 2     3012771  Morten Bruun fyret i SønderjyskE
# 3     3023463         Luderne flytter på landet
# 4     3032577    Cybersex: Hvornår er man utro?
#
#                                             subtitle  last_modified_time  \
# 0  Politiet frygter nu, at Nataschas bortfører ha... 2023-06-29 06:20:33
# 1  Biografgængerne strømmer ind for at se 'Da Vin... 2023-06-29 06:20:35
# 2  FODBOLD: Morten Bruun fyret med øjeblikkelig v... 2023-06-29 06:20:39
# 3  I landets tyndest befolkede områder skyder bor... 2023-06-29 06:20:43
# 4  En flirtende sms til den flotte fyr i regnskab... 2023-06-29 06:20:46
#
#    premium                                               body  \
# 0    False  Sagen om den østriske Natascha og hendes bortf...
# 1    False  Vatikanet har opfordret til at boykotte filmen...
# 2    False  Kemien mellem spillerne i Superligaklubben Søn...
# 3    False  Det frække erhverv rykker på landet. I den tyn...
# 4    False  De fleste af os mener, at et tungekys er utros...
#
#        published_time  image_ids     article_type  \
# 0 2006-08-31 08:06:45  [3150850]  article_default
# 1 2006-05-21 16:57:00  [3006712]  article_default
# 2 2006-05-01 14:28:40  [3177953]  article_default
# 3 2007-03-24 08:27:59  [3184029]  article_default
# 4 2007-01-18 10:30:37  [3030463]  article_default
#
#                                                  url  ... entity_groups  \
# 0   https://ekstrabladet.dk/krimi/article3001353.ece  ...            []
# 1  https://ekstrabladet.dk/underholdning/filmogtv...  ...            []
# 2  https://ekstrabladet.dk/sport/fodbold/dansk_fo...  ...            []
# 3  https://ekstrabladet.dk/nyheder/samfund/articl...  ...            []
# 4  https://ekstrabladet.dk/sex_og_samliv/article3...  ...            []
#
#                                               topics category  subcategory  \
# 0          [Kriminalitet, Personfarlig kriminalitet]      140           []
# 1               [Underholdning, Film og tv, Økonomi]      414   [433, 434]
# 2  [Erhverv, Kendt, Sport, Fodbold, Ansættelsesfo...      142   [196, 199]
# 3                                 [Livsstil, Erotik]      118        [133]
# 4                            [Livsstil, Partnerskab]      565           []
#
#     category_str total_inviews  total_pageviews  total_read_time  \
# 0          krimi           NaN              NaN              NaN
# 1  underholdning           NaN              NaN              NaN
# 2          sport           NaN              NaN              NaN
# 3        nyheder           NaN              NaN              NaN
# 4  sex_og_samliv           NaN              NaN              NaN
#
#    sentiment_score  sentiment_label
# 0           0.9955         Negative
# 1           0.8460         Positive
# 2           0.8241         Negative
# 3           0.7053          Neutral
# 4           0.9307          Neutral
#
# [5 rows x 21 columns]
# === Articles Null Counts ===
#    article_id  title  subtitle  last_modified_time  premium  body  \
# 0           0      0         0                   0        0     0
#
#    published_time  image_ids  article_type  url  ...  entity_groups  topics  \
# 0               0       1878             0    0  ...              0       0
#
#    category  subcategory  category_str  total_inviews  total_pageviews  \
# 0         0            0             0          10770            10882
#
#    total_read_time  sentiment_score  sentiment_label
# 0            10882                0                0
#
# [1 rows x 21 columns]

# %%
# 4. EDA on Test Behaviors
perform_eda(test_behavior_df, name="Test Behaviors")
# Out:
# === Test Behaviors Schema ===
# Schema([('impression_id', UInt32), ('article_id', Int32), ('impression_time', Datetime(time_unit='us', time_zone=None)), ('read_time', Float32), ('scroll_percentage', Float32), ('device_type', Int8), ('article_ids_inview', List(Int32)), ('article_ids_clicked', List(Int32)), ('user_id', UInt32), ('is_sso_user', Boolean), ('gender', Int8), ('postcode', Int8), ('age', Int8), ('is_subscriber', Boolean), ('session_id', UInt32), ('next_read_time', Float32), ('next_scroll_percentage', Float32)])
#
# === Test Behaviors describe() ===
#     statistic  impression_id    article_id             impression_time  \
# 0       count   2.446470e+05  7.130200e+04                      244647
# 1  null_count   0.000000e+00  1.733450e+05                           0
# 2        mean   2.888360e+08  9.774942e+06  2023-05-28 20:56:49.483729
# 3         std   1.666024e+08  1.501881e+05                        None
# 4         min   9.679100e+04  3.061199e+06         2023-05-25 07:00:02
# 5         25%   1.481505e+08  9.782074e+06         2023-05-27 04:51:44
# 6         50%   2.852676e+08  9.784782e+06         2023-05-28 21:19:56
# 7         75%   4.337364e+08  9.788024e+06         2023-05-30 15:03:44
# 8         max   5.795525e+08  9.791165e+06         2023-06-01 06:59:59
#
#        read_time  scroll_percentage    device_type  article_ids_inview  \
# 0  244647.000000       70481.000000  244647.000000            244647.0
# 1       0.000000      174166.000000       0.000000                 0.0
# 2      45.150528          99.560181       1.670513                 NaN
# 3      93.800919           4.884048       0.526633                 NaN
# 4       0.000000           7.000000       0.000000                 NaN
# 5      11.000000         100.000000       1.000000                 NaN
# 6      21.000000         100.000000       2.000000                 NaN
# 7      46.000000         100.000000       2.000000                 NaN
# 8    1799.000000         100.000000       3.000000                 NaN
#
#    article_ids_clicked       user_id    is_sso_user         gender  \
# 0             244647.0  2.446470e+05  244647.000000   16311.000000
# 1                  0.0  0.000000e+00       0.000000  228336.000000
# 2                  NaN  1.300233e+06       0.096948       0.095028
# 3                  NaN  7.434064e+05            NaN       0.293262
# 4                  NaN  1.020000e+04       0.000000       0.000000
# 5                  NaN  6.633500e+05            NaN       0.000000
# 6                  NaN  1.300443e+06            NaN       0.000000
# 7                  NaN  1.950529e+06            NaN       0.000000
# 8                  NaN  2.590637e+06       1.000000       1.000000
#
#         postcode            age  is_subscriber    session_id  next_read_time  \
# 0    4508.000000    6180.000000  244647.000000  2.446470e+05   237938.000000
# 1  240139.000000  238467.000000       0.000000  0.000000e+00     6709.000000
# 2       1.468722      54.773463       0.063647  9.972589e+05       69.044594
# 3       1.448976      14.193441            NaN  5.700954e+05      171.289978
# 4       0.000000      20.000000       0.000000  0.000000e+00        0.000000
# 5       0.000000      50.000000            NaN  5.032200e+05        7.000000
# 6       1.000000      60.000000            NaN  9.975400e+05       22.000000
# 7       3.000000      70.000000            NaN  1.491095e+06       64.000000
# 8       4.000000      90.000000       1.000000  2.036807e+06     1800.000000
#
#    next_scroll_percentage
# 0           214935.000000
# 1            29712.000000
# 2               69.067688
# 3               32.166965
# 4                0.000000
# 5               36.000000
# 6               79.000000
# 7              100.000000
# 8              100.000000
# === Test Behaviors head() ===
#    impression_id  article_id     impression_time  read_time  \
# 0          96791         NaN 2023-05-28 04:21:24        9.0
# 1          96798         NaN 2023-05-28 04:31:48       46.0
# 2          96801         NaN 2023-05-28 04:30:17       14.0
# 3          96808         NaN 2023-05-28 04:27:19       22.0
# 4          96810         NaN 2023-05-28 04:29:47       23.0
#
#    scroll_percentage  device_type  \
# 0                NaN            2
# 1                NaN            2
# 2                NaN            2
# 3                NaN            2
# 4                NaN            2
#
#                                   article_ids_inview article_ids_clicked  \
# 0      [9783865, 9784591, 9784679, 9784696, 9784710]           [9784696]
# 1  [9782884, 9783865, 9782726, 9695098, 9782806, ...           [9784281]
# 2  [9784648, 7184889, 9784444, 9781785, 9783405, ...           [9784444]
# 3      [9784607, 9695098, 9784406, 7184889, 9781983]           [9781983]
# 4  [9781983, 7184889, 9784642, 9782108, 9781785, ...           [9784642]
#
#    user_id  is_sso_user  gender  postcode  age  is_subscriber  session_id  \
# 0    22548        False     NaN       NaN  NaN          False         142
# 1    22548        False     NaN       NaN  NaN          False         143
# 2    22548        False     NaN       NaN  NaN          False         143
# 3    22548        False     NaN       NaN  NaN          False         142
# 4    22548        False     NaN       NaN  NaN          False         142
#
#    next_read_time  next_scroll_percentage
# 0            72.0                   100.0
# 1            16.0                    28.0
# 2            12.0                    24.0
# 3           125.0                    80.0
# 4             NaN                     NaN
# === Test Behaviors Null Counts ===
#    impression_id  article_id  impression_time  read_time  scroll_percentage  \
# 0              0      173345                0          0             174166
#
#    device_type  article_ids_inview  article_ids_clicked  user_id  is_sso_user  \
# 0            0                   0                    0        0            0
#
#    gender  postcode     age  is_subscriber  session_id  next_read_time  \
# 0  228336    240139  238467              0           0            6709
#
#    next_scroll_percentage
# 0                   29712

# %%
# 5. EDA on Processed Behaviors
perform_eda(processed_behavior_df, name="Processed Behaviors")
# Out:
# === Processed Behaviors Schema ===
# Schema([('user_id', UInt32), ('article_id', Int32), ('impression_time', Datetime(time_unit='us', time_zone=None)), ('score', Float64)])
#
# === Processed Behaviors describe() ===
#     statistic       user_id    article_id             impression_time  \
# 0       count  5.334900e+04  5.334900e+04                       53349
# 1  null_count  0.000000e+00  0.000000e+00                           0
# 2        mean  1.323950e+06  9.764742e+06  2023-05-21 18:14:12.956868
# 3         std  7.338987e+05  1.354391e+05                        None
# 4         min  1.006800e+04  3.198681e+06         2023-05-18 07:00:07
# 5         25%  6.976840e+05  9.772038e+06         2023-05-19 20:24:32
# 6         50%  1.341414e+06  9.774352e+06         2023-05-21 17:46:12
# 7         75%  1.962928e+06  9.776882e+06         2023-05-23 11:48:38
# 8         max  2.590571e+06  9.780271e+06         2023-05-25 06:59:56
#
#           score
# 0  52004.000000
# 1   1345.000000
# 2      0.627594
# 3      0.092245
# 4      0.192546
# 5      0.576248
# 6      0.633611
# 7      0.685020
# 8      0.998828
# === Processed Behaviors head() ===
#    user_id  article_id     impression_time     score
# 0  1447383     9770082 2023-05-18 18:14:32  0.714391
# 1   270347     9775985 2023-05-23 04:17:23  0.642377
# 2  1789758     9773070 2023-05-20 03:41:20  0.677369
# 3  1570306     9775484 2023-05-22 00:22:42  0.542215
# 4  2551003     9774079 2023-05-20 21:10:24  0.613608
# === Processed Behaviors Null Counts ===
#    user_id  article_id  impression_time  score
# 0        0           0                0   1345
