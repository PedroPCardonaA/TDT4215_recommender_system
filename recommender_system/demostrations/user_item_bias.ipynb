# %% [markdown]
# ## Demonstration of the User-Items Bias Baseline Recommender Model
# In this file, the demonstration of how the user-item bias baseline model recommends news for a user is presented.
# It also includes the evaluation of the recommender model by calculating the metrics *Precision@K and NDCG@K*.

# %%
import sys
import os

parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(parent_dir)
from utils.process_data import user_item_interaction_scores
from parquet_data_reader import ParquetDataReader
from models.baseline.user_item_bias import UserItemBiasRecommender


import polars as pl
pl.Config.set_tbl_cols(-1)
import numpy as np
parquet_reader = ParquetDataReader()

# %% [markdown]
# ### Reading the Data and Preprocessing

# %%
train_behavior_df = parquet_reader.read_data("../../data/train/behaviors.parquet")
embeddings_df = parquet_reader.read_data("../../data/document_vector.parquet")
article_df = parquet_reader.read_data("../../data/articles.parquet")
train_history_df = parquet_reader.read_data('../../data/train/history.parquet')
test_behavior_df = parquet_reader.read_data("../../data/validation/behaviors.parquet")
processed_behavior_df = user_item_interaction_scores(train_behavior_df, article=article_df)

# %% [markdown]
# ### Creates and Fits the Model to the Data

# %%
model = UserItemBiasRecommender(processed_behavior_df)
model.fit()

# %% [markdown]
# ### Recommendations
# Produces the recommended article-ids for the provided user id.
#
# It uses the function: *r_hat(u, i) = mu + b_u + b_i*

# %%
model.recommend(2423448)
# Out:
# [9514727, 9667501, 9714376, 9419945, 9761391]

# %%
model.predict(2423448,9714376)
# Out:
# 0.841934084892273

# %% [markdown]
# ### Evaluation
# Prints the *Precision@K and NDCG@K* metrics for the evaluation of the recommender.

# %%
results = model.evaluate_recommender(test_data=test_behavior_df,k=5,n_jobs=4,user_sample=1000)
print("Results")
results
# Out:
# Results
# {'MAP@K': np.float64(0.0002), 'NDCG@K': np.float64(0.0003391602052736161)}

# %% [markdown]
# Prints the common metrics for all models for comparison; Precision@k, recall@k and fpr@k

# %%
from utils.evaluation import append_model_metrics
from utils.evaluation import perform_model_evaluation

metrics = perform_model_evaluation(model, test_behavior_df, k=5)
print("Metrics")
print(metrics)

append_model_metrics(metrics, "baseline")
# Out:
# Metrics
# {'precision@k': np.float64(8.286148322054967e-05), 'recall@k': np.float64(2.224033152709503e-05), 'fpr@k': np.float64(0.002763542707662782)}

# %% [markdown]
# ### Diversity
# Calculates the aggrigate diversity of the recommender model recommendations, and appends the result to the `/evaluation_summary/model_overview_diversity.csv`-file.

# %%
users_ids = train_history_df['user_id'].unique()

# %%
from utils.evaluation import aggregate_diversity
from utils.evaluation import append_aggregate_diversity

diversity = aggregate_diversity(model, article_df, users_df=None, user_sample=1000)

print("Diversity")
print(diversity)

append_aggregate_diversity(diversity, "bias baseline")
# Out:
# Diversity
# 0.00024110328864885718

# %% [markdown]
# ### Carbon Footprint
# This section creates an emissions.csv file in the "output"-folder
# It utilizes the code_carbon (`codecarbon EmissionsTracker`) to record the carbon footprint of the `fit` and the `recommend` methods of the model.

# %%
from utils.evaluation import track_model_energy

print("\nCarbon footprint of the recommender:")
footprint = track_model_energy(model, "bias baseline", user_id=2423448, n=5)
footprint
# Out:
# [codecarbon INFO @ 12:45:52] [setup] RAM Tracking...
# [codecarbon INFO @ 12:45:52] [setup] CPU Tracking...
# [codecarbon WARNING @ 12:45:52] No CPU tracking mode found. Falling back on CPU constant mode.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
# Carbon footprint of the recommender:
# [codecarbon WARNING @ 12:45:54] We saw that you have a 13th Gen Intel(R) Core(TM) i7-13700H but we don't know it. Please contact us.
# [codecarbon INFO @ 12:45:54] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i7-13700H
# [codecarbon INFO @ 12:45:54] [setup] GPU Tracking...
# [codecarbon INFO @ 12:45:54] No GPU found.
# [codecarbon INFO @ 12:45:54] >>> Tracker's metadata:
# [codecarbon INFO @ 12:45:54]   Platform system: Windows-10-10.0.26100-SP0
# [codecarbon INFO @ 12:45:54]   Python version: 3.11.9
# [codecarbon INFO @ 12:45:54]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 12:45:54]   Available RAM : 15.731 GB
# [codecarbon INFO @ 12:45:54]   CPU count: 20
# [codecarbon INFO @ 12:45:54]   CPU model: 13th Gen Intel(R) Core(TM) i7-13700H
# [codecarbon INFO @ 12:45:54]   GPU count: None
# [codecarbon INFO @ 12:45:54]   GPU model: None
# [codecarbon INFO @ 12:45:57] Saving emissions data to file c:\Users\magnu\NewDesk\An.sys\TDT4215\recommender_system\demostrations\output\bias baseline_fit_emission.csv
# [codecarbon INFO @ 12:45:57] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.899243354797363 W
# [codecarbon INFO @ 12:45:57] Energy consumed for all CPUs : 0.000002 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:45:57] 0.000003 kWh of electricity used since the beginning.
# c:\Users\magnu\NewDesk\An.sys\TDT4215\venv\Lib\site-packages\codecarbon\output_methods\file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# [codecarbon INFO @ 12:45:57] [setup] RAM Tracking...
# [codecarbon INFO @ 12:45:57] [setup] CPU Tracking...
# [codecarbon WARNING @ 12:45:57] No CPU tracking mode found. Falling back on CPU constant mode.
#  Windows OS detected: Please install Intel Power Gadget to measure CPU
#
# [codecarbon WARNING @ 12:45:59] We saw that you have a 13th Gen Intel(R) Core(TM) i7-13700H but we don't know it. Please contact us.
# [codecarbon INFO @ 12:45:59] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i7-13700H
# [codecarbon INFO @ 12:45:59] [setup] GPU Tracking...
# [codecarbon INFO @ 12:45:59] No GPU found.
# [codecarbon INFO @ 12:45:59] >>> Tracker's metadata:
# [codecarbon INFO @ 12:45:59]   Platform system: Windows-10-10.0.26100-SP0
# [codecarbon INFO @ 12:45:59]   Python version: 3.11.9
# [codecarbon INFO @ 12:45:59]   CodeCarbon version: 2.8.3
# [codecarbon INFO @ 12:45:59]   Available RAM : 15.731 GB
# [codecarbon INFO @ 12:45:59]   CPU count: 20
# [codecarbon INFO @ 12:45:59]   CPU model: 13th Gen Intel(R) Core(TM) i7-13700H
# [codecarbon INFO @ 12:45:59]   GPU count: None
# [codecarbon INFO @ 12:45:59]   GPU model: None
# [codecarbon INFO @ 12:46:02] Saving emissions data to file c:\Users\magnu\NewDesk\An.sys\TDT4215\recommender_system\demostrations\output\bias baseline_recommend_emission.csv
# [codecarbon INFO @ 12:46:02] Energy consumed for RAM : 0.000000 kWh. RAM Power : 5.899243354797363 W
# [codecarbon INFO @ 12:46:02] Energy consumed for all CPUs : 0.000000 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 12:46:02] 0.000000 kWh of electricity used since the beginning.
# c:\Users\magnu\NewDesk\An.sys\TDT4215\venv\Lib\site-packages\codecarbon\output_methods\file.py:52: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame.from_records([dict(total.values)])])
# {'fit': (None, 8.368014679040478e-08),
#  'recommend': ([9514727, 9667501, 9714376, 9419945, 9761391],
#   4.35327482464344e-09)}

# %% [markdown]
# ### Gini coefficient

# %%
from utils.evaluation import append_gini_coefficient

gini = model.gini_coefficient(user_sample=1000)
print("Gini Coefficient")
gini

append_gini_coefficient(gini, "bias baseline")
# Out:
# Sampling users
# Computing Gini coefficient
# [9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 9761391, 9514727, 9667501, 9714376, 9419945, 976 ...
# Gini Coefficient
